# %%
# !pip install ultralytics matplotlib seaborn --quiet

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("yolov8n.pt")  # 'n' hafif, 's', 'm', 'l', 'x' daha büyük modeller

# Eğitimi başlat 
model.train(
    data="/Users/ahsennuraldas/Desktop/LicensePlateDetection/data.yaml",   # data.yaml dosyanın yolu
    epochs=50,
    imgsz=640,
    batch=4
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.127 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.126 🚀 Python-3.12.2 torch-2.6.0 CPU (Apple M2)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Grafik stilini belirleyelim
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# YOLOv8'in oluşturduğu results.csv dosyasını oku
df = pd.read_csv("runs/detect/train/results.csv")

# Epoch sütununu oluştur (0'dan başlar)
df["epoch"] = df.index
df.head()
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      0   5.82677         1.65648         5.13157         1.56374
# 1      1  11.74570         1.12266         4.68897         1.17980
# 2      2  17.74910         1.05190         3.31793         1.06753
# 3      3  23.51250         1.27711         2.84127         1.12383
# 4      4  29.34580         1.06259         2.63432         1.08098
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.00167            0.50000           0.00138
# 1               0.00278            0.83333           0.03623
# 2               0.00333            1.00000           0.31479
# 3               0.00333            1.00000           0.54901
# 4               0.00333            1.00000           0.61000
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.00077       1.33331       5.09582       1.46600  0.000120
# ...

# %%
plt.figure(figsize=(8, 4))
plt.plot(df["epoch"], df["train/box_loss"], label="Box Loss", color="red")
plt.xlabel("Epoch")
plt.ylabel("Box Loss")
plt.title("Box Loss (Bounding Box Kaybı)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(df["epoch"], df["metrics/mAP50(B)"], label="mAP@0.5", color="green")
plt.plot(df["epoch"], df["metrics/mAP50-95(B)"], label="mAP@0.5:0.95", color="blue")
plt.xlabel("Epoch")
plt.ylabel("mAP")
plt.title("mAP Zamanla Değişimi")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(df["epoch"], df["metrics/precision(B)"], label="Precision", color="orange")
plt.plot(df["epoch"], df["metrics/recall(B)"], label="Recall", color="purple")
plt.xlabel("Epoch")
plt.ylabel("Skor")
plt.title("Precision ve Recall")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os

# %%
model = YOLO("runs/detect/train/weights/best.pt")

# %%
test_images_path = "/Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/images"
image_files = [f for f in os.listdir(test_images_path) if f.endswith((".jpg", ".png", ".jpeg"))]

# %%
for image_file in image_files:
    image_path = os.path.join(test_images_path, image_file)

    # Tahmin yap
    results = model.predict(image_path, save=False, conf=0.25)

    # Görseli oku
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # BBox'ları çiz
    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = float(box.conf[0])
            label = int(box.cls[0])
            cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
            cv2.putText(img, f"{model.names[label]} {confidence:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    # Matplotlib ile göster
    plt.figure(figsize=(6, 6))
    plt.imshow(img)
    plt.title(f"Tahmin: {image_file}")
    plt.axis("off")
    plt.show()
# Out:
# image 1/1 /Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/images/IBqBWszPCap6HJ3C_jpeg.rf.8ebcb1b9908d4e248ff2ab2d3fd88cf0.jpg: 640x640 1 plate, 88.7ms
# Speed: 1.4ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/images/C4svWGuY8w08kv9B_jpeg.rf.56ef28615590855cb8ac9dd4960ba892.jpg: 640x640 1 plate, 70.6ms
# Speed: 1.6ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/images/0txdwQJANA69veu6_jpeg.rf.d080de66559064099c5fc3a4bd105d17.jpg: 640x640 1 plate, 71.9ms
# Speed: 1.0ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 /Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/images/2HcMYyw5U1M4sSAY_jpg.rf.0d93d979f97054d9bcb5ddb805b783bb.jpg: 640x640 (no detections), 71.7ms
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.126 🚀 Python-3.12.2 torch-2.6.0 CPU (Apple M2)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2510.1±699.6 MB/s, size: 76.2 KB)
# val: Scanning /Users/ahsennuraldas/Desktop/LicensePlateDetection/valid/labels.ca
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all          6          6          1      0.978      0.995       0.83
# Speed: 0.9ms preprocess, 66.2ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to runs/detect/val2

# %%
from PIL import Image

# Confusion matrix görseli yolunu ayarla
cm_path = "runs/detect/val/confusion_matrix.png"

# Göster
img = Image.open(cm_path)
plt.figure(figsize=(6,6), dpi=300)
plt.imshow(img)
plt.axis('off')
plt.title("Confusion Matrix")
plt.show()

# %%
# Precision
precision = metrics.box.mp
# Recall
recall = metrics.box.mr
# mAP@0.5
map50 = metrics.box.map50
# mAP@0.5:0.95
map = metrics.box.map

# %%
print(f"Precision:      {precision:.4f}")
print(f"Recall:         {recall:.4f}")
print(f"mAP@0.5:        {map50:.4f}")
print(f"mAP@0.5:0.95:   {map:.4f}")
# Out:
# Precision:      1.0000
# Recall:         0.9776
# mAP@0.5:        0.9950
# mAP@0.5:0.95:   0.8296

# %%
import matplotlib.pyplot as plt

labels = ["Precision", "Recall", "mAP@0.5", "mAP@0.5:0.95"]
values = [precision, recall, map50, map]

plt.figure(figsize=(6,4))
plt.bar(labels, values, color=["blue", "green", "orange", "red"])
plt.ylim(0, 1)
plt.title("YOLOv8 Performans Metrikleri")
plt.ylabel("Skor")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Resmi yükle ve model ile tespit yap
img_path = '/Users/ahsennuraldas/Desktop/images.jpeg'  # Yüklediğin resmin yolu
results = model(img_path)  # Resimdeki nesneleri tespit et
# Out:
# image 1/1 /Users/ahsennuraldas/Desktop/images.jpeg: 448x640 1 plate, 78.4ms
# Speed: 5.1ms preprocess, 78.4ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Sonuçları görselleştir
results[0].plot()  # Görselleştirilmiş sonucu göster
# Out:
# array([[[248, 248, 248],
#         [248, 248, 248],
#         [248, 248, 248],
#         ...,
#         [221, 206, 173],
#         [227, 215, 181],
#         [229, 217, 183]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241],
#         ...,
#         [234, 219, 186],
#         [239, 224, 192],
#         [237, 225, 191]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [233, 218, 186],
#         [236, 220, 191],
#         [235, 220, 188]],
#
#        ...,
#
#        [[136, 131, 130],
#         [138, 133, 132],
#         [142, 137, 136],
#         ...,
#         [247, 247, 247],
#         [252, 252, 252],
#         [253, 253, 253]],
#
#        [[168, 163, 162],
#         [170, 165, 164],
#         [173, 168, 167],
#         ...,
#         [244, 244, 244],
#         [249, 249, 249],
#         [251, 251, 251]],
#
#        [[185, 180, 179],
#         [187, 182, 181],
#         [190, 185, 184],
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# Sonuçları al
img = results[0].plot()  # Modelin tespit ettiği sonuçları al

# Görüntü üzerinde kutuları çizme
plt.imshow(img)  # Görüntüyü matplotlib ile göster
plt.axis('off')  # Eksenleri kapat
plt.show()

# %%
pip install pytesseract pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
from PIL import Image
import numpy as np

# %%
# Orijinal resmi tekrar oku (çünkü .plot() sonrası çizilmiş resim oluyor)
from ultralytics import YOLO
import cv2

# Resmi oku
image_path = '/Users/ahsennuraldas/Desktop/images.jpeg'
original_img = cv2.imread(image_path)

# YOLOv8 ile tahmin al (tekrar)
results = model(image_path)

# İlk tespit sonucundaki bounding box'ı al (ilk obje varsayılarak)
boxes = results[0].boxes
xyxy = boxes.xyxy[0].cpu().numpy().astype(int)  # [x1, y1, x2, y2]

# ROI (Region of Interest) = plaka bölgesi
plate_img = original_img[xyxy[1]:xyxy[3], xyxy[0]:xyxy[2]]

# OCR için RGB formatına çevir
plate_rgb = cv2.cvtColor(plate_img, cv2.COLOR_BGR2RGB)

# Görselleştir (isteğe bağlı)
from matplotlib import pyplot as plt

plt.imshow(plate_rgb)
plt.title("Tespit Edilen Plaka")
plt.axis('off')
plt.show()
# Out:
# image 1/1 /Users/ahsennuraldas/Desktop/images.jpeg: 448x640 1 plate, 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
# OCR ile plakayı oku
text = pytesseract.image_to_string(plate_rgb, config='--psm 8')  # psm 8: tek bir kelime veya plaka için ideal
print("Tespit Edilen Plaka:", text.strip())
# Out:
# Tespit Edilen Plaka: "34 GS 19051
